# %%
from itertools import *
import random
import math
#import matplotlib.pyplot as plt

x = []
instru = []

def insertion_short(A):
    comparaciones = 0
    intercambios = 0
    for i in range(1,len(A)):
        temp = A[i]
        j = i
        comparaciones += 1
        while j > 0 and temp < A[j-1]:
            if j != i:
                comparaciones += 1
            A[j] = A[j-1]
            j = j-1
            intercambios += 1
        A[j] = temp
        if j > 0 and j != i:
            comparaciones += 1

    instrucciones = comparaciones + intercambios
    resultados = []
    resultados.append(instrucciones)
    resultados.append(comparaciones)
    resultados.append(intercambios)
    return resultados

for n in range(2,10):
    perm = []
    A = list(i for i in range(n))
    acum_ins = 0
    acum_c = 0
    acum_int = 0
    n1 = random.randint(1, math.factorial(n))
    permutaciones = list(permutations(A))
    random.shuffle(permutaciones)
    #print(permutaciones)
    #print(n1)
    for a in range(n1):
        #print(a)
        acum = insertion_short(list(permutaciones[a]))
        acum_ins += acum[0]
        acum_c += acum[1]
        acum_int += acum[2]
        #print(permutaciones)

    print('ARREGLO DE TAMAÑO {}'.format(n))
    print('Número aleatorio de permutaciones: {}'.format(n1))
    print('La cantidad de instrucciones promedio es: {}'.format(float(acum_ins / n1)))
    print('La cantidad de comparaciones promedio es: {}'.format(float(acum_c / n1)))
    print('La cantidad de intercambios promedio es: {}'.format(float(acum_int / n1)))
    print('-----------------------')
    x.append(n)
    instru.append(float(acum_ins / n1))

#plt.plot(x, instru)
#plt.xlabel('Tamaño arreglo')
#plt.ylabel('Cantidad de instrucciones promedio')
#plt.title('Instrucciones')
#plt.show()
# Out:
# ARREGLO DE TAMAÑO 2
# Número aleatorio de permutaciones: 1
# La cantidad de instrucciones promedio es: 1.0
# La cantidad de comparaciones promedio es: 1.0
# La cantidad de intercambios promedio es: 0.0
# -----------------------
# ARREGLO DE TAMAÑO 3
# Número aleatorio de permutaciones: 3
# La cantidad de instrucciones promedio es: 3.6666666666666665
# La cantidad de comparaciones promedio es: 2.3333333333333335
# La cantidad de intercambios promedio es: 1.3333333333333333
# -----------------------
# ARREGLO DE TAMAÑO 4
# Número aleatorio de permutaciones: 12
# La cantidad de instrucciones promedio es: 7.916666666666667
# La cantidad de comparaciones promedio es: 5.0
# La cantidad de intercambios promedio es: 2.9166666666666665
# -----------------------
# ARREGLO DE TAMAÑO 5
# Número aleatorio de permutaciones: 101
# La cantidad de instrucciones promedio es: 12.811881188118813
# La cantidad de comparaciones promedio es: 7.782178217821782
# La cantidad de intercambios promedio es: 5.02970297029703
# -----------------------
# ARREGLO DE TAMAÑO 6
# Número aleatorio de permutaciones: 419
# La cantidad de instrucciones promedio es: 18.780429594272075
# La cantidad de comparaciones promedio es: 11.140811455847256
# La cantidad de intercambios promedio es: 7.639618138424821
# -----------------------
# ARREGLO DE TAMAÑO 7
# Número aleatorio de permutaciones: 3523
# La cantidad de instrucciones promedio es: 25.43627590122055
# La cantidad de comparaciones promedio es: 14.919103037184218
# La cantidad de intercambios promedio es: 10.517172864036333
# -----------------------
# ARREGLO DE TAMAÑO 8
# Número aleatorio de permutaciones: 3454
# La cantidad de instrucciones promedio es: 33.4160393746381
# La cantidad de comparaciones promedio es: 19.345975680370586
# La cantidad de intercambios promedio es: 14.070063694267516
# -----------------------
# ARREGLO DE TAMAÑO 9
# Número aleatorio de permutaciones: 160837
# La cantidad de instrucciones promedio es: 42.168941226210386
# La cantidad de comparaciones promedio es: 24.170265548350194
# La cantidad de intercambios promedio es: 17.998675677860195
# -----------------------
