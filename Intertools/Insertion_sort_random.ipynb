# %%
from itertools import *
import random
import math
import matplotlib.pyplot as plt


def insertion_short(A):
    comparaciones = 0
    intercambios = 0
    for i in range(1,len(A)):
        temp = A[i]
        j = i
        comparaciones += 1
        while j > 0 and temp < A[j-1]:
            if j != i:
                comparaciones += 1
            A[j] = A[j-1]
            j = j-1
            intercambios += 1
        A[j] = temp
        if (j > 0 and j != i and temp > A[j - 1]) or (j != i and j == 0):
            comparaciones += 1

    instrucciones = comparaciones + intercambios
    resultados = []
    resultados.append(instrucciones)
    resultados.append(comparaciones)
    resultados.append(intercambios)
    return resultados

for n in range(2,11):
    perm = []
    A = list(i for i in range(n))
    acum_ins = 0
    acum_c = 0
    acum_int = 0
    n1 = random.randint(1, math.factorial(n))
    permutaciones = list(permutations(A))
    random.shuffle(permutaciones)
    #print(permutaciones)
    #print(n1)
    for a in range(n1):
        #print(a)
        acum = insertion_short(list(permutaciones[a]))
        acum_ins += acum[0]
        acum_c += acum[1]
        acum_int += acum[2]
        #print(permutaciones)

    print('ARREGLO DE TAMAÑO {}'.format(n))
    print('Número aleatorio de permutaciones: {}'.format(n1))
    print('La cantidad de instrucciones promedio es: {}'.format(float(acum_ins / n1)))
    print('La cantidad de comparaciones promedio es: {}'.format(float(acum_c / n1)))
    print('La cantidad de intercambios promedio es: {}'.format(float(acum_int / n1)))
    print('-----------------------')
# Out:
# ARREGLO DE TAMAÑO 2
# Número aleatorio de permutaciones: 1
# La cantidad de instrucciones promedio es: 1.0
# La cantidad de comparaciones promedio es: 1.0
# La cantidad de intercambios promedio es: 0.0
# -----------------------
# ARREGLO DE TAMAÑO 3
# Número aleatorio de permutaciones: 6
# La cantidad de instrucciones promedio es: 5.0
# La cantidad de comparaciones promedio es: 3.5
# La cantidad de intercambios promedio es: 1.5
# -----------------------
# ARREGLO DE TAMAÑO 4
# Número aleatorio de permutaciones: 9
# La cantidad de instrucciones promedio es: 9.0
# La cantidad de comparaciones promedio es: 6.0
# La cantidad de intercambios promedio es: 3.0
# -----------------------
# ARREGLO DE TAMAÑO 5
# Número aleatorio de permutaciones: 18
# La cantidad de instrucciones promedio es: 13.88888888888889
# La cantidad de comparaciones promedio es: 8.944444444444445
# La cantidad de intercambios promedio es: 4.944444444444445
# -----------------------
# ARREGLO DE TAMAÑO 6
# Número aleatorio de permutaciones: 55
# La cantidad de instrucciones promedio es: 19.945454545454545
# La cantidad de comparaciones promedio es: 12.472727272727273
# La cantidad de intercambios promedio es: 7.472727272727273
# -----------------------
# ARREGLO DE TAMAÑO 7
# Número aleatorio de permutaciones: 3004
# La cantidad de instrucciones promedio es: 26.992676431424766
# La cantidad de comparaciones promedio es: 16.496338215712385
# La cantidad de intercambios promedio es: 10.496338215712383
# -----------------------
# ARREGLO DE TAMAÑO 8
# Número aleatorio de permutaciones: 27060
# La cantidad de instrucciones promedio es: 34.981818181818184
# La cantidad de comparaciones promedio es: 20.990909090909092
# La cantidad de intercambios promedio es: 13.99090909090909
# -----------------------
# ARREGLO DE TAMAÑO 9
# Número aleatorio de permutaciones: 135135
# La cantidad de instrucciones promedio es: 44.00803640803641
# La cantidad de comparaciones promedio es: 26.004018204018205
# La cantidad de intercambios promedio es: 18.004018204018205
# -----------------------
# ARREGLO DE TAMAÑO 10
# Número aleatorio de permutaciones: 1708701
# La cantidad de instrucciones promedio es: 54.000053256830775
# La cantidad de comparaciones promedio es: 31.500026628415387
# La cantidad de intercambios promedio es: 22.500026628415387
# -----------------------
