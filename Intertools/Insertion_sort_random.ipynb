# %%
from itertools import *
import random
import math
import matplotlib.pyplot as plt

# %%
def insertion_short(A):

    comparaciones = 0
    intercambios = 0
    instrucciones = 0
    for i in range(1,len(A)):
        temp = A[i]
        j = i - 1
        while j > -1 and temp < A[j]:
            comparaciones += 1
            A[j+1] = A[j]
            j = j-1
            intercambios += 1
            instrucciones += 3
        instrucciones += 1
        A[j+1] = temp
        instrucciones += 4

        if j != i:
            comparaciones += 1

    instrucciones += 1
    resultados = []
    resultados.append(instrucciones)
    resultados.append(comparaciones)
    resultados.append(intercambios)
    return resultados

# %%
for n in range(2,11):
    perm = []
    A = list(i for i in range(n))
    acum_ins = 0
    acum_c = 0
    acum_int = 0
    n1 = random.randint(1, math.factorial(n))
    permutaciones = list(permutations(A))
    random.shuffle(permutaciones)
    for a in range(n1):
        acum = insertion_short(list(permutaciones[a]))
        acum_ins += acum[0]
        acum_c += acum[1]
        acum_int += acum[2]

    print('ARREGLO DE TAMAÑO {}'.format(n))
    print('Número aleatorio de permutaciones: {}'.format(n1))
    print('La cantidad de instrucciones promedio es: {}'.format(float(acum_ins / n1)))
    print('La cantidad de comparaciones promedio es: {}'.format(float(acum_c / n1)))
    print('La cantidad de intercambios promedio es: {}'.format(float(acum_int / n1)))
    print('-----------------------')
# Out:
# ARREGLO DE TAMAÑO 2
# Número aleatorio de permutaciones: 2
# La cantidad de instrucciones promedio es: 7.5
# La cantidad de comparaciones promedio es: 1.5
# La cantidad de intercambios promedio es: 0.5
# -----------------------
# ARREGLO DE TAMAÑO 3
# Número aleatorio de permutaciones: 1
# La cantidad de instrucciones promedio es: 11.0
# La cantidad de comparaciones promedio es: 2.0
# La cantidad de intercambios promedio es: 0.0
# -----------------------
# ARREGLO DE TAMAÑO 4
# Número aleatorio de permutaciones: 14
# La cantidad de instrucciones promedio es: 25.214285714285715
# La cantidad de comparaciones promedio es: 6.071428571428571
# La cantidad de intercambios promedio es: 3.0714285714285716
# -----------------------
# ARREGLO DE TAMAÑO 5
# Número aleatorio de permutaciones: 77
# La cantidad de instrucciones promedio es: 35.45454545454545
# La cantidad de comparaciones promedio es: 8.818181818181818
# La cantidad de intercambios promedio es: 4.818181818181818
# -----------------------
# ARREGLO DE TAMAÑO 6
# Número aleatorio de permutaciones: 354
# La cantidad de instrucciones promedio es: 48.38135593220339
# La cantidad de comparaciones promedio es: 12.46045197740113
# La cantidad de intercambios promedio es: 7.46045197740113
# -----------------------
# ARREGLO DE TAMAÑO 7
# Número aleatorio de permutaciones: 2639
# La cantidad de instrucciones promedio es: 62.31413414172035
# La cantidad de comparaciones promedio es: 16.438044713906784
# La cantidad de intercambios promedio es: 10.438044713906782
# -----------------------
# ARREGLO DE TAMAÑO 8
# Número aleatorio de permutaciones: 18537
# La cantidad de instrucciones promedio es: 77.99498300695906
# La cantidad de comparaciones promedio es: 20.998327668986352
# La cantidad de intercambios promedio es: 13.998327668986352
# -----------------------
# ARREGLO DE TAMAÑO 9
# Número aleatorio de permutaciones: 291177
# La cantidad de instrucciones promedio es: 94.98254669839994
# La cantidad de comparaciones promedio es: 25.994182232799982
# La cantidad de intercambios promedio es: 17.994182232799982
# -----------------------
# ARREGLO DE TAMAÑO 10
# Número aleatorio de permutaciones: 2378906
# La cantidad de instrucciones promedio es: 113.50459917289712
# La cantidad de comparaciones promedio es: 31.501533057632376
# La cantidad de intercambios promedio es: 22.501533057632376
# -----------------------
